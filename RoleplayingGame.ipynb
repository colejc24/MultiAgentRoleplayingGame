# %%
from autogen import ConversableAgent, GroupChat, GroupChatManager
from secret import SECRET_KEY

#Unused right now
human_proxy = ConversableAgent(
    "human_proxy",
    llm_config=False,
    human_input_mode="ALWAYS",
)

dungeonMaster = ConversableAgent(
    "DM",
    system_message="You are a dungeon master for a tabletop role-playing game.",
    llm_config={"config_list": [{"model": "gpt-3.5-turbo", "temperature": 0.9, "api_key": SECRET_KEY}]},
    code_execution_config=False,
    function_map=None,
    human_input_mode="NEVER",
)

goblinPlayer = ConversableAgent(
    "goblinPlayer",
    system_message="You are a player in a tabletop role-playing game. You are playing as a Goblin Bard who grew up as a theif.",
    llm_config={"config_list": [{"model": "gpt-3.5-turbo", "temperature": 0.9, "api_key": SECRET_KEY}]},
    code_execution_config=False,
    function_map=None,
    human_input_mode="NEVER",
)

elfPlayer = ConversableAgent(
    "elfPlayer",
    system_message="You are a player in a tabletop role-playing game. You are playing as an Elven Archer who grew up as a high prince.",
    llm_config={"config_list": [{"model": "gpt-3.5-turbo", "temperature": 0.9, "api_key": SECRET_KEY}]},
    code_execution_config=False,
    function_map=None,
    human_input_mode="NEVER",
)

dwarfPlayer = ConversableAgent(
    "dwarfPlayer",
    system_message="You are a player in a tabletop role-playing game. You are playing as an Dwarf Warrior who grew up in the mines.",
    llm_config={"config_list": [{"model": "gpt-3.5-turbo", "temperature": 0.9, "api_key": SECRET_KEY}]},
    code_execution_config=False,
    function_map=None,
    human_input_mode="NEVER",
)

group_chat = GroupChat(
    agents=[dungeonMaster, goblinPlayer, elfPlayer, dwarfPlayer, human_proxy],
    messages=[],
    max_round=10,
)

group_chat_manager = GroupChatManager(
    groupchat=group_chat,
    llm_config={"config_list": [{"model": "gpt-3.5-turbo", "api_key": SECRET_KEY}]},
)

chat_result = dungeonMaster.initiate_chat(
    group_chat_manager,
    message="Start a new game of Dungeons and Dragons.",
    summary_methods="reflection_with_llm"
)
# Out:
# DM (to chat_manager):
#
# Start a new game of Dungeons and Dragons.
#
# --------------------------------------------------------------------------------
#
# Next speaker: DM
#
# DM (to chat_manager):
#
# Welcome, adventurers, to the world of Elandria! As you gather around the table, the flickering torchlight casts shadows on the ancient stone walls of the dungeon you find yourselves in. You have been drawn together by fate, each with your own unique skills and abilities. Are you ready to embark on a grand adventure filled with danger, treasure, and mystery?
#
# Please introduce your characters to the group and let me know what brings you to this dark and foreboding place.
#
# --------------------------------------------------------------------------------
#
# Next speaker: elfPlayer
#
# elfPlayer (to chat_manager):
#
# I am Thaladir, an Elven Archer and high prince of the enchanted forest of Eldoria. My keen eyes and expert bowmanship have long been honed in defense of my kingdom. I am here seeking to prove my worth outside of the familiar walls of my homeland, to test my abilities against the challenges of the wider world.
#
# As I stand tall and proud in my shimmering silver armor, my long silver hair cascades down my back like a waterfall. I carry a finely crafted bow made from the branches of the ancient trees of Eldoria, and my quiver is filled with arrows tipped with enchanted silver.
#
# I trust in my skills with the bow to guide me through this dungeon. My keen senses will help us navigate the dark corridors and my steady hand will strike true against any foes that cross our path. Let us embark on this adventure, my companions, and together we shall overcome any obstacle that stands in our way.
#
# --------------------------------------------------------------------------------
#
# Next speaker: goblinPlayer
#
# goblinPlayer (to chat_manager):
#
# As the Elf Prince Thaladir finishes his introduction, the torchlight flickers and casts an ominous glow on the walls of the dungeon. The air grows tense as the other adventurers turn their attention to the Goblin Bard sitting beside Thaladir. With a mischievous grin and a glint in his eye, the Goblin begins to speak.
#
# "Greetings, fellow adventurers! My name is Snikkle, and I may not come from the lofty realms of the elves or the grand kingdoms of men, but I bring something just as valuable to our party - a quick wit, a silver tongue, and a knack for getting us out of sticky situations.
#
# I grew up on the rough streets of the city, where I learned to survive by my wits and my nimble fingers. I honed my skills as a thief, a pickpocket, and a con artist, but I also discovered a talent for music and storytelling. Now, armed with my trusty lute and a repertoire of songs and tales, I am ready to join you on this adventure and help steer our fate in a more... harmonious direction.
#
# So, let's not waste any time standing around in the shadows. I say we march boldly forward, through whatever dangers lie ahead, and make our mark on this world with song, trickery, and a dash of goblin cunning! What say you, my friends?"
#
# --------------------------------------------------------------------------------
#
# Next speaker: DM
#
# DM (to chat_manager):
#
# The rest of the party listens intently to Snikkle's charismatic introduction, intrigued by the Goblin Bard's combination of roguish charm and musical talent. With Thaladir's keen senses and Snikkle's quick thinking, the group feels confident in their diverse abilities as they prepare to face the challenges of the dungeon ahead.
#
# As the torch sputters and the shadows lengthen, the party knows that their adventure is about to begin. With Thaladir's bow at the ready and Snikkle's lute strung, they set off down the dark corridors, their footsteps echoing on the cold stone floor.
#
# The dungeon is filled with twists and turns, traps and monsters lurking around every corner. But with the Elven Archer and the Goblin Bard leading the way, the party faces each challenge with skill and cunning, working together to overcome whatever obstacles come their way.
#
# As they delve deeper into the depths of the dungeon, the party's bond grows stronger with each victory and each shared moment of danger. And as they press on, guided by Thaladir's keen eyes and Snikkle's clever words, they know that no matter what trials await them, they will face them as a united team, ready to conquer the perils of the dungeon and emerge victorious on the other side.
#
# --------------------------------------------------------------------------------
#
# Next speaker: human_proxy
